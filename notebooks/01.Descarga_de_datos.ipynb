# %%
import pandas as pd

# %% [markdown]
# CARGA Y CONSOLIDACION DEL DATASET

# %%
#cargamos el dataset
df_2009 = pd.read_csv("data/2009_1perc.csv", encoding= "latin-1")
df_2010 = pd.read_csv("data/2010_1perc.csv", encoding= "latin-1")

#consolidamos ambos set
# Verificar que ambos DataFrames tienen la misma estructura de columnas
if list(df_2009.columns) == list(df_2010.columns):
    # Concatenar los DataFrames
    df_consolidado = pd.concat([df_2009, df_2010], ignore_index=True)
    print('Los archivos han sido consolidados.')
else:
    print('Los DataFrames tienen estructuras de columnas diferentes')
# Out:
# Los archivos han sido consolidados.

# %%
df_consolidado.to_csv("data/consolidado.csv", index=False)

# %%
df_consolidado.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11825 entries, 0 to 11824
# Columns: 112 entries, Unnamed: 0 to detailcm
# dtypes: float64(1), int64(16), object(3), str(92)
# memory usage: 11.9+ MB

# %% [markdown]
# EXPLORACION BASICA
#
# Obtenemos información básica del dataset: número de filas/columnas, tipos de datos, estadísticas básicas y número de vacios por variable.

# %%
print(f"El DataFrame consolidado tiene {df_consolidado.shape[0]} filas y {df_consolidado.shape[1]} columnas.")

object_count = (df_consolidado.dtypes == 'object').sum()
print(f"Numero de variables tipo object: {object_count}")
object_count = (df_consolidado.dtypes == 'str').sum()
print(f"Numero de variables tipo string: {object_count}")
# Contar cuántas variables son de tipo 'integer'
integer_count = (df_consolidado.dtypes == 'int').sum() + (df_consolidado.dtypes == 'int64').sum()
print(f"Numbero de variables tipo entero: {integer_count}")
# Contar cuántas variables son de tipo 'float'
float_count = (df_consolidado.dtypes == 'float').sum() + (df_consolidado.dtypes == 'float64').sum()
print(f"Numbero de variables tipo float: {float_count}")
missing_values = df_consolidado.isnull().sum()
print(f"Numbero valores perdidos: {missing_values}")
print("-------------")
print("Estadisticos del dataset")
df_consolidado.describe().T
# Out:
# El DataFrame consolidado tiene 11825 filas y 112 columnas.
# Numero de variables tipo object: 3
# Numero de variables tipo string: 92
# Numbero de variables tipo entero: 32
# Numbero de variables tipo float: 2
# Numbero valores perdidos: Unnamed: 0    0
# year          0
# pct           0
# ser_num       0
# datestop      0
#              ..
# xcoord        0
# ycoord        0
# dettypcm      0
# linecm        0
# detailcm      0
# Length: 112, dtype: int64
# -------------
# Estadisticos del dataset
#           Unnamed: 0          year           pct       ser_num      datestop  \
# count   11825.000000  11825.000000  11825.000000  11825.000000  1.182500e+04
# mean   295983.814799   2009.508499     68.625624   5697.994334  6.364221e+06
# std    170820.705702      0.499949     33.037826   5152.486022  3.429091e+06
# min        52.000000   2009.000000      1.000000      1.000000  1.012009e+06
# 25%    147515.000000   2009.000000     42.000000   2002.000000  3.232009e+06
# 50%    296652.000000   2010.000000     73.000000   4366.000000  6.162010e+06
# 75%    443097.000000   2010.000000    102.000000   7840.000000  9.232009e+06
# max    601281.000000   2010.000000    123.000000  31694.000000  1.231201e+07
#
#            timestop        perobs       perstop  compyear  comppct  \
# count  11825.000000  11825.000000  11825.000000   11825.0  11825.0
# mean    1413.725497      2.654391      5.649556       0.0      0.0
# std      744.726359      9.759031      9.758535       0.0      0.0
# min        0.000000      0.000000      1.000000       0.0      0.0
# 25%     1000.000000      1.000000      3.000000       0.0      0.0
# 50%     1605.000000      1.000000      5.000000       0.0      0.0
# 75%     2035.000000      3.000000      5.000000       0.0      0.0
# max     2830.000000    926.000000    857.000000       0.0      0.0
#
#              repcmd        revcmd           dob           age       ht_feet  \
# count  11825.000000  11825.000000  1.182500e+04  11825.000000  11825.000000
# mean     243.354926    238.986385  7.316195e+06     28.968541      5.183340
# std      297.788599    299.394740  3.729206e+06     29.205278      0.398801
# min        1.000000      1.000000  1.011900e+06      1.000000      3.000000
# 25%       70.000000     66.000000  4.121982e+06     19.000000      5.000000
# 50%      105.000000    103.000000  7.261982e+06     25.000000      5.000000
# 75%      177.000000    176.000000  1.105199e+07     34.000000      5.000000
# max      879.000000    879.000000  1.231200e+07    999.000000      7.000000
#
#             ht_inch        weight
# count  11825.000000  11825.000000
# mean       6.408034    170.093615
# std        3.405503     37.195884
# min        0.000000      1.000000
# 25%        4.000000    150.000000
# 50%        7.000000    170.000000
# 75%        9.000000    180.000000
# max       11.000000    999.000000

# %% [markdown]
# Algunas observaciones acerca del dataset:
#
# La varible "age" está en unidades de años, por lo que algunos datos de la variable "age" son incosistentes como el max= 999
# La varible "weight" está en kilos o libras por lo que algunos datos de la variable "weight" son inconsistentes como max= 999

# %% [markdown]
# Se eliminan las siguientes variables ya que son de identificación única (no aportan generalización)
# ser_num	ID único
# officrid	ID del oficial
# addrnum	    Número exacto dirección
# premname	Nombre específico lugar
# aptnum	    Apartamento
# xcoord	    Coordenada exacta
# ycoord	    Coordenada exacta
#
# Se eliminan  las siguientes variables ya que tienen alta granularidad textual
# stname	    Miles de calles
# crossst	    Alta cardinalidad
# stinter	    Alta cardinalidad
# othfeatr	Texto libre
# crimsusp	Texto ambiguo
# ac_other	Texto ambiguo
# cs_other	Texto libre
# sb_other	Texto libre
#
# Se eliminan variables redundantes o poco utiles
# dob	 Ya existe age
# zip	 Muy granular
# post Poco valor predictivo

# %%
cols_to_drop = [
    "ser_num", "officrid", "arstoffn", "sumissue", "sumoffen",
    "revcmd", "detailcm", "linecm", "dettypcm",
    "addrnum", "premname", "aptnum", "xcoord", "ycoord",
    "dob", "stname", "crossst", "stinter", "othfeatr",
    "cs_other", "sb_other", "ac_other"
]
df_consolidado.drop(columns=cols_to_drop, inplace=True)

df_consolidado.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11825 entries, 0 to 11824
# Data columns (total 90 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  11825 non-null  int64
#  1   year        11825 non-null  int64
#  2   pct         11825 non-null  int64
#  3   datestop    11825 non-null  int64
#  4   timestop    11825 non-null  int64
#  5   recstat     11825 non-null  str
#  6   inout       11825 non-null  str
#  7   trhsloc     11825 non-null  str
#  8   perobs      11825 non-null  float64
#  9   crimsusp    11825 non-null  str
#  10  perstop     11825 non-null  int64
#  11  typeofid    11825 non-null  str
#  12  explnstp    11825 non-null  str
#  13  othpers     11825 non-null  str
#  14  arstmade    11825 non-null  str
#  15  compyear    11825 non-null  int64
#  16  comppct     11825 non-null  int64
#  17  offunif     11825 non-null  str
#  18  frisked     11825 non-null  str
#  19  searched    11825 non-null  str
#  20  contrabn    11825 non-null  str
#  21  adtlrept    11825 non-null  str
#  22  pistol      11825 non-null  str
#  23  riflshot    11825 non-null  str
#  24  asltweap    11825 non-null  str
#  25  knifcuti    11825 non-null  str
#  26  machgun     11825 non-null  str
#  27  othrweap    11825 non-null  str
#  28  pf_hands    11825 non-null  str
#  29  pf_wall     11825 non-null  str
#  30  pf_grnd     11825 non-null  str
#  31  pf_drwep    11825 non-null  str
#  32  pf_ptwep    11825 non-null  str
#  33  pf_baton    11825 non-null  str
#  34  pf_hcuff    11825 non-null  str
#  35  pf_pepsp    11825 non-null  str
#  36  pf_other    11825 non-null  str
#  37  radio       11825 non-null  str
#  38  ac_rept     11825 non-null  str
#  39  ac_inves    11825 non-null  str
#  40  rf_vcrim    11825 non-null  str
#  41  rf_othsw    11825 non-null  str
#  42  ac_proxm    11825 non-null  str
#  43  rf_attir    11825 non-null  str
#  44  cs_objcs    11825 non-null  str
#  45  cs_descr    11825 non-null  str
#  46  cs_casng    11825 non-null  str
#  47  cs_lkout    11825 non-null  str
#  48  rf_vcact    11825 non-null  str
#  49  cs_cloth    11825 non-null  str
#  50  cs_drgtr    11825 non-null  str
#  51  ac_evasv    11825 non-null  str
#  52  ac_assoc    11825 non-null  str
#  53  cs_furtv    11825 non-null  str
#  54  rf_rfcmp    11825 non-null  str
#  55  ac_cgdir    11825 non-null  str
#  56  rf_verbl    11825 non-null  str
#  57  cs_vcrim    11825 non-null  str
#  58  cs_bulge    11825 non-null  str
#  59  ac_incid    11825 non-null  str
#  60  ac_time     11825 non-null  str
#  61  rf_knowl    11825 non-null  str
#  62  ac_stsnd    11825 non-null  str
#  63  sb_hdobj    11825 non-null  str
#  64  sb_outln    11825 non-null  str
#  65  sb_admis    11825 non-null  str
#  66  repcmd      11825 non-null  int64
#  67  rf_furt     11825 non-null  str
#  68  rf_bulg     11825 non-null  str
#  69  offverb     11825 non-null  str
#  70  offshld     11825 non-null  str
#  71  sex         11825 non-null  str
#  72  race        11825 non-null  str
#  73  age         11825 non-null  int64
#  74  ht_feet     11825 non-null  int64
#  75  ht_inch     11825 non-null  int64
#  76  weight      11825 non-null  int64
#  77  haircolr    11825 non-null  str
#  78  eyecolor    11825 non-null  str
#  79  build       11825 non-null  str
#  80  addrtyp     11825 non-null  str
#  81  rescode     11825 non-null  str
#  82  premtype    11825 non-null  str
#  83  city        11825 non-null  str
#  84  state       11825 non-null  str
#  85  zip         11825 non-null  str
#  86  addrpct     11825 non-null  object
#  87  sector      11825 non-null  str
#  88  beat        11825 non-null  str
#  89  post        11825 non-null  str
# dtypes: float64(1), int64(13), object(1), str(75)
# memory usage: 9.1+ MB
